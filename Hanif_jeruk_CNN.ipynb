# %%
# !nvidia-smi
# Out:
# Thu Apr 16 04:51:27 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.9/175.9 kB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 89.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 120.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="HlSflsM672Rb6qMCkZLk")
project = rf.workspace("zein-ojgj9").project("jeruk_final")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to jeruk_final-1 in yolov9:: 100%|██████████| 5023/5023 [00:00<00:00, 6069.29it/s]

# %%
# Ultralytics
from ultralytics import YOLO
model = YOLO("yolov9c.pt")
model.info()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# YOLOv9c summary: 358 layers, 25,590,912 parameters, 0 gradients, 104.0 GFLOPs
# (358, 25590912, 0, 104.02268160000003)

# %%
model.train(
    data="/content/jeruk_final-1/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import yaml

with open('/content/jeruk_final-1/data.yaml', 'r') as f:
    data = yaml.safe_load(f)

if 'names' in data:
    print("Classes:", data['names'])
else:
    print("Class names not found in the YAML file.")
# Out:
# Classes: ['jeruk busuk', 'jeruk matang besar', 'jeruk matang sedang', 'jeruk mentah']

# %%
import torch
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Load model
model = YOLO('//content/runs/detect/train/weights/best.pt')

# Load image and make predictions
image_path = '/content/jeruk1.jpg'
results = model(image_path)

# Plot the results on the image
annotated_image = results[0].plot()

# Display the annotated image
plt.figure(figsize=(10, 8))
plt.imshow(annotated_image)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/jeruk1.jpg: 640x512 1 jeruk matang besar, 1 jeruk mentah, 36.8ms
# Speed: 2.7ms preprocess, 36.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)

# %%
# !zip -r  runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 4%)
#   adding: content/runs/detect/train/train_batch12421.jpg (deflated 7%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 2%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 12%)
#   adding: content/runs/detect/train/BoxR_curve.png (deflated 15%)
#   adding: content/runs/detect/train/val_batch2_labels.jpg (deflated 11%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train/results.png (deflated 10%)
#   adding: content/runs/detect/train/train_batch12420.jpg (deflated 9%)
#   adding: content/runs/detect/train/confusion_matrix_normalized.png (deflated 24%)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/runs.zip /content/drive/MyDrive/
